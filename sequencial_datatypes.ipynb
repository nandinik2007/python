# %% [markdown]
# ## Sequentail data types
#
# These are collectiosn of items that are ordered and indexed.
#
# -- Items(element) -> a simply one piece of data strore inside a sequeitial data type.
# -- Think of it as aone slot or one piece in your collection.
#
#
# -- Each  element has a specific poistion (index)
# -- Yon can access elemest by their posstion number
# -- The order of elements matters and is presever

# %% [markdown]
# ## List
# A list is like a container that holds multiple itesm in order.
# - To-do-list, shopping list;
# where
# - Items are kept in a specific order
# - You can add, remove or change items
# - Each item has a position number (starting from 0)

# %% [markdown]
# # Creation and indexing/slicing
# - Creating lists and acessing elemts or sub lists using indices(0 - based) and slices ([start:stop:step])

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]
student_counts = [350, 420, 380, 500, 450]

# %%
first_course = course_list[1]
first_course
# Out:
# 'Data Engineering'

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]

last_course = course_list[-2]
last_course
# Out:
# 'Python Basics'

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]

counts_slce = course_list[1:4] 
counts_slce
# Out:
# ['Data Engineering', 'Azure DevOps', 'Python Basics']

# %%
# get every second course starting from the first 
course_list = ["Data Science", "Data Engineering", "Azure DevOps", "Python Basics", "SQL Fundamentals"]
every_second_course = course_list[::2]
every_second_course
# Out:
# ['Data Science', 'Azure DevOps', 'SQL Fundamentals']

# %%
# Creatin a list with mixed data types 
batch_info = ["DE101", "Data Engineering", 45, True] # ID, Nmae, Size, Active 
batch_info[1][1:-3]
# Out:
# 'ata Engineer'

# %%
batch_size = batch_info[2]
batch_size
# Out:
# 45

# %%
batch_info = ["DE101", "Data Engineering", 45, True] # ID, Nmae, Size, Active 
 #

# %%
# acces last two itesms using slicing 
last_two_items = batch_info[-2:]   # [start: end : (optional)]
last_two_items
# Out:
# ['Data Engineering', 45, True]

# %%
str1= "Datascience"
str1[0] = "E"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 str1= "Datascience"
# ----> 2 str1[0] = "E"
#
# TypeError: 'str' object does not support item assignment

# %%
batch_info = ["DE101", "Data Engineering", 45, True]
batch_info[1] = "Data Science"

# %%
batch_info
# Out:
# ['DE101', 'Data Science', 45, True]

# %%
upcoming_courses = []
upcoming_courses
# Out:
# []

# %% [markdown]
# # list.append(item)    -- append = add
# -- Adds a single iteml to the end of the list. Modifies the list in-place(changes will be made in original list).

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
new_enrollments = [15, 20, 10]

# %%
course_list
# Out:
# ['Data Science', 'Data Engineering', 'Azure DevOps']

# %%
# Add a new course to the list 
course_list.append("Cloud Computing")
course_list
# Out:
# ['Data Science', 'Data Engineering', 'Azure DevOps', 'Cloud Computing']

# %%
# another course 
course_list.append("Mahcine learning")

# %%
course_list
# Out:
# ['Data Science',
#  'Data Engineering',
#  'Azure DevOps',
#  'Cloud Computing',
#  'Mahcine learning']

# %%
new_enrollments = [15, 20, 10]

# %%
# appedn a num to a list of numbers 
new_enrollments.append(18)
new_enrollments
# Out:
# [15, 20, 10, 18]

# %%
# Append a list as single item (nested list)
meta_list = [1, 2]
meta_list.append([3,4])
meta_list
# Out:
# [1, 2, [3, 4]]

# %%
batch_student = ["Alice", "Bob"]
batch_student.append("Charlie")
batch_student
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
batch_student[2]
# Out:
# 'Charlie'

# %%
feedback_scores = []
feedback_scores.append(5)
feedback_scores.append(4)
feedback_scores.append(5)
feedback_scores
# Out:
# [5, 4, 5]

# %%
colors = [] # empty list

color1 = input("Enter fist color: ")
colors.append(color1)

color2 = input("Enter 2nd color: ")
colors.append(color2)

color3 = input("Enter 3rd color: ")
colors.append(color3)

color4 = input("Enter 4th color: ")
colors.append(color4)

# %%
colors
# Out:
# ['Blue ', 'Red ', 'Grey', 'Black']

# %% [markdown]
# ## list.extent(iterable)
# -- Adds all the itesm from an iterable (like another list or string) to the end of the current lsit.
#
# -- modifies in place

# %%
data_science_courses = ["DS Intro", "Python for DS"]
data_eng_courses = ["DE Intro", "SQL for DE", "ADF"]

# %%
data_science_courses.append(data_eng_courses)
data_science_courses
# Out:
# ['DS Intro', 'Python for DS', ['DE Intro', 'SQL for DE', 'ADF']]

# %%
data_science_courses[2]
# Out:
# ['DE Intro', 'SQL for DE', 'ADF']

# %%
data_science_courses.extend(data_eng_courses)
data_science_courses
# Out:
# ['DS Intro', 'Python for DS', 'DE Intro', 'SQL for DE', 'ADF']

# %%
data_science_courses[-1]
# Out:
# 'ADF'

# %%
batch_1_studnets = ["alice", 'bob']
batch_2_studnets = ["charlie", "David"]
batch_1_studnets.extend(batch_2_studnets)

# %%
batch_1_studnets
# Out:
# ['alice', 'bob', 'charlie', 'David']

# %%
# extend with a stering 
letters = ['a', 'b']
letters.extend("cde")
letters
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
letters = ['a', 'b']
letters.append("cde")
letters
# Out:
# ['a', 'b', 'cde']

# %%
empty_list1 = []
empty_list1.append([1,2,3])
empty_list1[0]
# Out:
# [1, 2, 3]

# %%
empty_list2 = []
empty_list2.extend([1,2,3])
empty_list2[2]
# Out:
# 3

# %%
print(len(empty_list1))   # append  , reversing [0:end:-1]
print(len(empty_list2))     # extend
# Out:
# 1
# 3

# %%
sameple = "My name is lohit"
sameple[::-1]
# Out:
# 'tihol si eman yM'

# %%
empty_list = []
new_list = list()

# %%
empty_list.append("Whatever")
empty_list
# Out:
# ['Whatever', 'Whatever', 'Whatever', 'Whatever']

# %%
new_list.append("why")
new_list
# Out:
# ['however', 'however', 'when', 'why']

# %%
new_list    # Modifies in place
# Out:
# ['however', 'however', 'when', 'why']

# %% [markdown]
# ## list.insert(index, item)
# -- Insert an item at a specific index. Existing items from the index will be shifted to right.
#
# -- Modifies in place.

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
priority_tasks = ["Deploy App", "Monitor Logs"]

# %%
course_list.append("Python basics")
course_list.extend("Python basics")

# %%
course_list.insert(0, "Python Basics")

# %%
course_list
# Out:
# ['Python Basics', 'Data Science', 'Data Engineering', 'Azure DevOps']

# %%
course_list.insert(, "Cloud Intro")
course_list
# Out:
#   Cell In[53], line 1
#     course_list.insert(, "Cloud Intro")
#                        ^
# SyntaxError: invalid syntax

# %%
numbers = [1, 2, 3, 5]
numbers.insert(3,4)
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = [1, 2, 3, 5]
numbers.insert(-1,4)
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
# if i want to insert at index equal to lenght of list 
tasks = ["Task A", "Task B"]   # len
tasks.insert(, "Task C")
tasks
# Out:
# ['Task A', 'Task B', 'Task C']

# %% [markdown]
#        ["Task A", "Task B", "  2   "] -> 2, 3, 4, 5, 6
#        [0,          1,        2     ]
#  -5,-4 [-3,         -2,        -1  ]

# %%
tasks[2]
# Out:
# 'Task C'

# %%
tasks = ["Task A", "Task B"]
len(tasks) - 10
# Out:
# -8

# %%
# nested list 
nested = [1, [3, 4]]      # oupout = [1, 2, [3, 4]]
nested.insert(1, 2)
nested
# Out:
# [1, 2, [3, 4]]

# %%
nested[2].append(5)
nested
# Out:
# [1, 2, [3, 4, 5]]

# %%
# [1, 2, [3, 6, 4, 5]]
nested[2].insert(1,6)
nested
# Out:
# [1, 2, [3, 6, 4, 5]]

# %%
nested[2].insert(2,5)
nested
# Out:
# [1, 2, [3, 4, 5]]

# %%
# created empty list 
# added elements using -> append, extend, insert

# %% [markdown]
# ### list.remove(item)
# -- Removes the first occurence of the specified item from the list.
#
# -- Raise ValueError if the item is not found.
#
# -- Modifies the list in-place

# %%
course_list = ["Python Basics", "Data Science", "Cloud Intro", "Data Engineering", "Data Science"]
tools = ["Python", "SQL", "Git", "SQL"]

# %%
print(course_list)
course_list.remove("Cloud Intro")
print(course_list)
# Out:
# ['Python Basics', 'Data Science', 'Cloud Intro', 'Data Engineering', 'Data Science']
# ['Python Basics', 'Data Science', 'Data Engineering', 'Data Science']

# %%
print(course_list)
course_list.remove('Data Science')
print(course_list)
# Out:
# ['Python Basics', 'Data Science', 'Data Engineering', 'Data Science']
# ['Python Basics', 'Data Engineering', 'Data Science']

# %%
print(course_list)
course_list.remove('Data Science')
print(course_list)
# Out:
# ['Python Basics', 'Data Engineering', 'Data Science']
# ['Python Basics', 'Data Engineering']

# %%
print(course_list)
course_list.remove('Data Science')
print(course_list)
# Out:
# ['Python Basics', 'Data Engineering']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 2
#       1 print(course_list)
# ----> 2 course_list.remove('Data Science')
#       3 print(course_list)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### list.pop([index])
#
# -- Removes and returns the items at the given index.
#
# -- If index is omitted. it removes and returns the last item.
#
# -- Raise IndexError if the list is empty or the index is out of range.

# %%
course_list = ["Python Basics", "Data Science", "Data Engineering"]
tasks = ["Review Code", "Update Docs", "Deploy"]

# %%
last_course = course_list.pop()
last_course
# Out:
# 'Data Engineering'

# %%
first_course = course_list.pop(0)
first_course
# Out:
# 'Python Basics'

# %%
course_list = ["Python Basics", "Data Science", "Data Engineering"]

middle_course = course_list.pop(1)
middle_course
# Out:
# 'Data Science'
